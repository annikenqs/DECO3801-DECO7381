# %%
import os
from langchain_huggingface import HuggingFaceEndpoint
from langchain_core.prompts import ChatPromptTemplate

HF = os.getenv("HF_TOKEN") or os.getenv("HUGGINGFACEHUB_API_TOKEN")
assert HF, "Set HF_TOKEN or HUGGINGFACEHUB_API_TOKEN first."

model_A = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="conversational",             
    huggingfacehub_api_token=HF,
    temperature=0.2,
    max_new_tokens=256,
)

model_B = HuggingFaceEndpoint(
    repo_id="Qwen/Qwen2.5-VL-7B-Instruct",
    task="conversational",             
    huggingfacehub_api_token=HF,
    temperature=0.2,
    max_new_tokens=256,
)

model_C = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-v0.1",
    task="conversational",             
    huggingfacehub_api_token=HF,
    temperature=0.2,
    max_new_tokens=256,
)
